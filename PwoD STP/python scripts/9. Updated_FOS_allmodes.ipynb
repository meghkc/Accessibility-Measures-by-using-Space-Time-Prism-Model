# %%
import arcpy
from arcpy import na 
import arcpy.nax
import os
import time

modes= ['Transit','Drive']#['Bike','Walk','Transit','Drive']

def calculate_travel_time(mode, origin_shp_path, travel_time_field, hptripid_field_name):
    # Create a mapping for the mode to the respective field in ODCostMatrix and SearchCursor
    mode_field_mapping = {
        'Walk': 'Mins_PedOnly',
        'Bike': 'Mins_BikeOnly',
        'Drive': 'Mins_DriveOnly',
        'Transit': 'Mins_PedTransitOnly'
    }
    mode_field = mode_field_mapping[mode]

    # Process each hptripid value in the origin shapefile
    with arcpy.da.SearchCursor(origin_shp_path, [hptripid_field_name]) as cursor:
        for row in cursor:
            hptripid = row[0]
            converted_hptripid = hptripid.replace('.', '_')
            int_shp_path = os.path.join(int_service_points_dir, f"POI_{mode}_{converted_hptripid}.shp")

            if arcpy.Exists(int_shp_path) and any(row[0] == hptripid for row in arcpy.da.SearchCursor(int_shp_path, [hptripid_field_name])):
                # Create a new OD Cost Matrix layer for the current hptripid
                out_od_cost_matrix = arcpy.na.MakeODCostMatrixLayer(network_dataset, 
                                                                    "ODCostMatrix", 
                                                                    mode_field
                                                                    )
                out_od_cost_matrix_object = out_od_cost_matrix.getOutput(0)

                sublayer_names = arcpy.na.GetNAClassNames(out_od_cost_matrix_object)
                origins_sublayer_name = sublayer_names["Origins"]
                destinations_sublayer_name = sublayer_names["Destinations"]

                # Delete rows from the Origins and Destinations sublayers to ensure they are empty
                arcpy.DeleteRows_management(origins_sublayer_name)
                arcpy.DeleteRows_management(destinations_sublayer_name)

                # Create a temporary feature layer for the specific hptripid
                temp_layer_name = "temp_origin_layer"
                arcpy.MakeFeatureLayer_management(origin_shp_path, temp_layer_name, f"{hptripid_field_name} = '{hptripid}'")

                # Set the search tolerance
                search_tolerance = "300 Meters"
                search_criteria = [["BikePedAuto", "SHAPE"]]
                
                # Add this temporary layer as the origins
                arcpy.na.AddLocations(out_od_cost_matrix_object, "Origins", temp_layer_name, field_mappings="", 
                                      snap_to_position_along_network="SNAP", snap_offset="300 Meters",
                                      search_tolerance=search_tolerance, search_criteria=search_criteria)

                # Delete the temporary layer
                arcpy.Delete_management(temp_layer_name)

                # Add the destinations
                arcpy.na.AddLocations(out_od_cost_matrix_object, "Destinations", int_shp_path,field_mappings="Name int_OBJID #",
                                      snap_to_position_along_network="SNAP", snap_offset="300 Meters",
                                    search_tolerance=search_tolerance,search_criteria=search_criteria
                                        )

                # Solve the OD Cost Matrix
                arcpy.na.Solve(out_od_cost_matrix_object, terminate_on_solve_error="CONTINUE")

                # Directly assign the name of the lines sublayer
                lines_sublayer = "Lines"

                with arcpy.da.SearchCursor(lines_sublayer, ["OriginID", "DestinationID", f"Total_{mode_field}"]) as sCursor:
                    for sRow in sCursor:
                        origin_id = sRow[0]
                        dest_id = sRow[1]
                        travel_time = sRow[2]

                        # Update the travel time field in the int_shp_path shapefile with the computed travel time
                        with arcpy.da.UpdateCursor(int_shp_path, ["int_OBJID", travel_time_field]) as uCursor:
                            for uRow in uCursor:
                                if uRow[0] == dest_id:  # Assuming that int_OBJID matches the DestinationID
                                    uRow[1] = travel_time
                                    uCursor.updateRow(uRow)

                # Optionally delete this OD matrix layer to save memory
                arcpy.Delete_management(out_od_cost_matrix_object)

                # Save the updated shapefile to the output directory
                output_shp_path = os.path.join(output_directory, f"FOS_{mode}_{converted_hptripid}.shp")
                arcpy.CopyFeatures_management(int_shp_path, output_shp_path)

            else:
                print(f"Shapefile {int_shp_path} does not exist. Skipping...")

def remove_rows_based_on_total_time(origin_shp_path, output_directory, hptripid_field_name):
    with arcpy.da.SearchCursor(origin_shp_path, [hptripid_field_name, 'Total_T']) as cursor:
        for row in cursor:
            hptripid = row[0]
            total_t = row[1]
            converted_hptripid = hptripid.replace('.', '_')
            output_shp_path = os.path.join(output_directory, f"FOS_{mode}_{converted_hptripid}.shp")
            
            # Check if the shapefile exists
            if arcpy.Exists(output_shp_path):
                # Rows to be deleted
                rows_to_delete = []
                # First, look for rows where either trav_t or trav_t_itd is 0
                with arcpy.da.SearchCursor(output_shp_path, ['OID@', 'trav_t', 'trav_t_itd']) as zero_check_cursor:
                    for zero_row in zero_check_cursor:
                        if zero_row[1] == 0 or zero_row[2] == 0:
                            rows_to_delete.append(zero_row[0])
                
                # If any rows were marked for deletion, delete them
                if rows_to_delete:
                    with arcpy.da.UpdateCursor(output_shp_path, ['OID@']) as del_cursor:
                        for del_row in del_cursor:
                            if del_row[0] in rows_to_delete:
                                del_cursor.deleteRow()

                # Reset the rows_to_delete list for the next check
                rows_to_delete = []
                # Calculate the sum of trav_t and trav_t_itd for each row and compare
                with arcpy.da.SearchCursor(output_shp_path, ['OID@', 'trav_t', 'trav_t_itd']) as travel_cursor:
                    for travel_row in travel_cursor:
                        oid = travel_row[0]
                        sum_travel_time = (travel_row[1] or 0) + (travel_row[2] or 0)
                        if total_t < sum_travel_time:
                            rows_to_delete.append(oid)
                # Delete rows that don't meet the criteria
                if rows_to_delete:
                    with arcpy.da.UpdateCursor(output_shp_path, ['OID@']) as del_cursor:
                        for del_row in del_cursor:
                            if del_row[0] in rows_to_delete:
                                del_cursor.deleteRow()

                # Print the Total_T value and remaining counts
                remaining_count = arcpy.GetCount_management(output_shp_path)
                print(f"For hptripid {hptripid} with Total_T value of {total_t}:")
                print(f"Shapefile {output_shp_path} has {remaining_count} rows remaining.")
                print("-"*50)  # separator for clarity

def add_and_populate_fields(mode, int_service_points_dir):
    # List all the shapefiles in the directory
    shapefiles = [f for f in os.listdir(int_service_points_dir) if f.endswith('.shp')]
    
    # Loop through each shapefile
    for shp in shapefiles:
        # Check if the shapefile name matches the format "POI_{mode}_{hptripid}.shp"
        if shp.startswith(f"POI_{mode}_"):
            # Construct the full path to the shapefile
            shp_path = os.path.join(int_service_points_dir, shp)
            
            # Add a new field named "int_OBJECTID" with data type "LONG"
            arcpy.AddField_management(shp_path, "int_OBJID", "LONG")
            arcpy.AddField_management(shp_path, "trav_t", "DOUBLE")
            arcpy.AddField_management(shp_path, "trav_t_itd", "DOUBLE")

            # Populate the new field with values starting from 1
            with arcpy.da.UpdateCursor(shp_path, "int_OBJID") as cursor:
                count = 1
                for row in cursor:
                    row[0] = count
                    cursor.updateRow(row)
                    count += 1

# Record the start time
start_time = time.time()  

# Set environment
workspace = rf"E:\Space-Time-Prism-Model\PwoD STP\MyPwoDSTPProject\MyPwoDSTPProject.gdb"
arcpy.env.workspace = workspace
arcpy.env.overwriteOutput = True 

network_dataset = fr"E:\Space-Time-Prism-Model\PwoD STP\MM_NetworkDataset_03092022.gdb\NetworkDataset\NetworkDataset_ND"

for mode in modes:
    origin_shp_path = rf"E:\Space-Time-Prism-Model\PwoD STP\Data\Data_Shapefiles\origin_{mode}_filtered.shp"
    destn_shp_path = rf"E:\Space-Time-Prism-Model\PwoD STP\Data\Data_Shapefiles\destn_{mode}_filtered.shp"
    int_service_points_dir = rf"E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\{mode}_POI_after_ser_hr\Reprojected"
    output_directory = rf"E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\{mode}_FOS"
    if not os.path.exists(output_directory):
        os.makedirs(output_directory, exist_ok=True)

    # Call the function to add and populate fields for each mode-specific shapefile
    add_and_populate_fields(mode, int_service_points_dir)  

    hptripid_field_origin = [field.name for field in arcpy.ListFields(origin_shp_path) if field.name.lower() == 'hptripid'][0]
    hptripid_field_destn = [field.name for field in arcpy.ListFields(destn_shp_path) if field.name.lower() == 'hptripid'][0]

    # Calculate travel time for origin shapefile
    calculate_travel_time(mode, origin_shp_path, "trav_t", hptripid_field_origin)
    # Calculate travel time for destination shapefile
    calculate_travel_time(mode, destn_shp_path, "trav_t_itd", hptripid_field_destn)
    # Call the function to remove rows based on the given criteria
    remove_rows_based_on_total_time(origin_shp_path, output_directory, hptripid_field_origin)

    # Record the end time
    end_time = time.time()
    # Calculate the total processing time
    processing_time = end_time - start_time
    print(f"The script took {processing_time} seconds to complete.")
# Out:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Transit_POI_after_ser_hr\Reprojected\POI_Transit_W13499RZ_02_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Transit_POI_after_ser_hr\Reprojected\POI_Transit_W16652KT_02_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Transit_POI_after_ser_hr\Reprojected\POI_Transit_W23874BC_01_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Transit_POI_after_ser_hr\Reprojected\POI_Transit_W23874BC_01_02.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Transit_POI_after_ser_hr\Reprojected\POI_Transit_W23925TX_02_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Transit_POI_after_ser_hr\Reprojected\POI_Transit_W24464TE_05_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Transit_POI_after_ser_hr\Reprojected\POI_Transit_W26444NF_01_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Transit_POI_after_ser_hr\Reprojected\POI_Transit_W26444NF_01_02.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Transit_POI_after_ser_hr\Reprojected\POI_Transit_W27232TE_01_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Transit_POI_after_ser_hr\Reprojected\POI_Transit_W27292SX_03_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Transit_POI_after_ser_hr\Reprojected\POI_Transit_W27612AS_01_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Transit_POI_after_ser_hr\Reprojected\POI_Transit_W27612AS_01_03.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Transit_POI_after_ser_hr\Reprojected\POI_Transit_W27612AS_01_05.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Transit_POI_after_ser_hr\Reprojected\POI_Transit_W28489WK_02_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Transit_POI_after_ser_hr\Reprojected\POI_Transit_W29523EN_01_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Transit_POI_after_ser_hr\Reprojected\POI_Transit_W29523EN_01_02.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Transit_POI_after_ser_hr\Reprojected\POI_Transit_W13499RZ_02_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Transit_POI_after_ser_hr\Reprojected\POI_Transit_W16652KT_02_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Transit_POI_after_ser_hr\Reprojected\POI_Transit_W23874BC_01_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Transit_POI_after_ser_hr\Reprojected\POI_Transit_W23874BC_01_02.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Transit_POI_after_ser_hr\Reprojected\POI_Transit_W23925TX_02_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Transit_POI_after_ser_hr\Reprojected\POI_Transit_W24464TE_05_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Transit_POI_after_ser_hr\Reprojected\POI_Transit_W26444NF_01_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Transit_POI_after_ser_hr\Reprojected\POI_Transit_W26444NF_01_02.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Transit_POI_after_ser_hr\Reprojected\POI_Transit_W27232TE_01_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Transit_POI_after_ser_hr\Reprojected\POI_Transit_W27292SX_03_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Transit_POI_after_ser_hr\Reprojected\POI_Transit_W27612AS_01_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Transit_POI_after_ser_hr\Reprojected\POI_Transit_W27612AS_01_03.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Transit_POI_after_ser_hr\Reprojected\POI_Transit_W27612AS_01_05.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Transit_POI_after_ser_hr\Reprojected\POI_Transit_W28489WK_02_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Transit_POI_after_ser_hr\Reprojected\POI_Transit_W29523EN_01_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Transit_POI_after_ser_hr\Reprojected\POI_Transit_W29523EN_01_02.shp does not exist. Skipping...
# For hptripid W33205TD.03.01 with Total_T value of 145:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Transit_FOS\FOS_Transit_W33205TD_03_01.shp has 9760 rows remaining.
# --------------------------------------------------
# For hptripid W33205TD.03.02 with Total_T value of 160:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Transit_FOS\FOS_Transit_W33205TD_03_02.shp has 17982 rows remaining.
# --------------------------------------------------
# For hptripid W37283RF.01.01 with Total_T value of 20:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Transit_FOS\FOS_Transit_W37283RF_01_01.shp has 401 rows remaining.
# --------------------------------------------------
# For hptripid W42090FN.01.03 with Total_T value of 20:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Transit_FOS\FOS_Transit_W42090FN_01_03.shp has 0 rows remaining.
# --------------------------------------------------
# For hptripid W42090FN.01.04 with Total_T value of 120:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Transit_FOS\FOS_Transit_W42090FN_01_04.shp has 2957 rows remaining.
# --------------------------------------------------
# For hptripid W43344MN.01.06 with Total_T value of 20:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Transit_FOS\FOS_Transit_W43344MN_01_06.shp has 0 rows remaining.
# --------------------------------------------------
# For hptripid W43344MN.01.07 with Total_T value of 40:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Transit_FOS\FOS_Transit_W43344MN_01_07.shp has 0 rows remaining.
# --------------------------------------------------
# For hptripid W44624KU.02.03 with Total_T value of 380:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Transit_FOS\FOS_Transit_W44624KU_02_03.shp has 39330 rows remaining.
# --------------------------------------------------
# For hptripid W46367UK.02.01 with Total_T value of 580:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Transit_FOS\FOS_Transit_W46367UK_02_01.shp has 26235 rows remaining.
# --------------------------------------------------
# For hptripid W55065KC.02.01 with Total_T value of 155:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Transit_FOS\FOS_Transit_W55065KC_02_01.shp has 19674 rows remaining.
# --------------------------------------------------
# For hptripid W57574RB.01.01 with Total_T value of 35:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Transit_FOS\FOS_Transit_W57574RB_01_01.shp has 549 rows remaining.
# --------------------------------------------------
# For hptripid W57574RB.01.02 with Total_T value of 20:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Transit_FOS\FOS_Transit_W57574RB_01_02.shp has 73 rows remaining.
# --------------------------------------------------
# For hptripid W58713CB.02.01 with Total_T value of 70:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Transit_FOS\FOS_Transit_W58713CB_02_01.shp has 6424 rows remaining.
# --------------------------------------------------
# For hptripid W58713CB.02.02 with Total_T value of 70:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Transit_FOS\FOS_Transit_W58713CB_02_02.shp has 4896 rows remaining.
# --------------------------------------------------
# For hptripid W59810TS.03.02 with Total_T value of 15:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Transit_FOS\FOS_Transit_W59810TS_03_02.shp has 134 rows remaining.
# --------------------------------------------------
# For hptripid W61462BM.04.01 with Total_T value of 45:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Transit_FOS\FOS_Transit_W61462BM_04_01.shp has 1055 rows remaining.
# --------------------------------------------------
# For hptripid W61462BM.04.02 with Total_T value of 30:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Transit_FOS\FOS_Transit_W61462BM_04_02.shp has 112 rows remaining.
# --------------------------------------------------
# For hptripid W61948SW.01.01 with Total_T value of 55:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Transit_FOS\FOS_Transit_W61948SW_01_01.shp has 834 rows remaining.
# --------------------------------------------------
# For hptripid W61948SW.01.02 with Total_T value of 85:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Transit_FOS\FOS_Transit_W61948SW_01_02.shp has 4548 rows remaining.
# --------------------------------------------------
# For hptripid W63925KU.01.01 with Total_T value of 30:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Transit_FOS\FOS_Transit_W63925KU_01_01.shp has 1376 rows remaining.
# --------------------------------------------------
# For hptripid W63925KU.01.02 with Total_T value of 125:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Transit_FOS\FOS_Transit_W63925KU_01_02.shp has 12644 rows remaining.
# --------------------------------------------------
# For hptripid W71237DB.02.02 with Total_T value of 45:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Transit_FOS\FOS_Transit_W71237DB_02_02.shp has 1882 rows remaining.
# --------------------------------------------------
# For hptripid W71830XD.01.01 with Total_T value of 405:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Transit_FOS\FOS_Transit_W71830XD_01_01.shp has 34859 rows remaining.
# --------------------------------------------------
# For hptripid W75043NH.04.01 with Total_T value of 260:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Transit_FOS\FOS_Transit_W75043NH_04_01.shp has 30620 rows remaining.
# --------------------------------------------------
# For hptripid W75996TF.01.01 with Total_T value of 275:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Transit_FOS\FOS_Transit_W75996TF_01_01.shp has 37688 rows remaining.
# --------------------------------------------------
# For hptripid W77202HE.01.01 with Total_T value of 25:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Transit_FOS\FOS_Transit_W77202HE_01_01.shp has 1308 rows remaining.
# --------------------------------------------------
# The script took 139318.39621710777 seconds to complete.
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_M20048UA_02_02.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_M20048UA_02_05.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_M20048UA_03_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_M24065HB_01_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_M24065HB_01_03.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_M24065HB_01_05.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_M33710ZH_02_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_M33710ZH_02_02.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_M33710ZH_02_03.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_M33710ZH_02_06.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_M33710ZH_02_11.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W17928SZ_02_03.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W20535EH_01_03.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W23778NE_02_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W23778NE_02_02.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W23778NE_02_03.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W23778NE_02_04.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W23778NE_02_05.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W25159US_02_04.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W25159US_02_06.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W25159US_02_08.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W25344FD_02_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W25877UH_01_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W25877UH_01_02.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W26145XE_02_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W26733BF_02_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W27343WX_02_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W27343WX_02_03.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W27384RR_02_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W27384RR_02_02.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W27655EA_02_02.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W27662ST_01_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W27662ST_01_07.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W27662ST_01_09.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W27662ST_02_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W27662ST_02_02.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W27662ST_02_04.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W27662ST_02_05.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W27662ST_02_06.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W27662ST_02_08.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W28268SZ_01_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W28268SZ_01_03.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W28445HK_02_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W28792EX_01_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W28792EX_01_02.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W28792EX_01_04.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W28792EX_01_05.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W28846FN_01_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W28861XX_01_03.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W29156RE_01_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W29156RE_01_05.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W31314UB_03_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W31314UB_03_02.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W32448SX_01_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W32448SX_01_03.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W32448SX_01_05.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W32448SX_01_07.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W33379KX_01_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W33379KX_01_02.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W33923FF_02_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W33923FF_02_02.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W33923FF_02_04.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W34761FT_01_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W34761FT_01_02.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W34761FT_01_05.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W34761FT_01_06.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W34761FT_01_07.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W34776KF_01_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W34776KF_01_03.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W34776KF_01_05.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W34776KF_01_08.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W34776KF_01_09.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W34988WF_04_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W37069HK_02_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W37535FZ_02_02.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W37535FZ_02_06.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W37535FZ_02_08.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W37537AM_01_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W38111AK_02_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W38111AK_02_02.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W39416ZN_01_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W39416ZN_02_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W39695DU_02_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W39695DU_02_03.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W39841UC_01_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W39841UC_01_03.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W39976SX_02_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W39976SX_02_03.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W40041KR_01_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W40621XK_03_02.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W40741BZ_02_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W40741BZ_02_06.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W40741BZ_02_09.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W42470EN_01_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W42470EN_01_04.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W43344MN_01_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W44595NN_02_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W44595NN_02_03.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W44692RS_01_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W44692RS_01_02.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W45837XD_01_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W47240WZ_01_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W47240WZ_01_03.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W47240WZ_01_05.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W47726KT_01_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W48262HD_01_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W48262HD_01_04.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W48262HD_01_06.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W48600XX_01_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W48600XX_01_02.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W48600XX_01_03.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W48600XX_01_04.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W48600XX_01_05.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W48600XX_01_06.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W48600XX_01_07.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W48600XX_01_08.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W49565XW_01_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W49565XW_01_04.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W49700HH_02_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W50212KB_01_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W50392SK_01_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W50698HX_01_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W51650AR_01_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W51760FC_01_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W52217KX_03_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W52217KX_04_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W52217KX_04_08.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W52762XK_02_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W52762XK_02_06.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W53120SD_01_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W53120SD_01_02.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W53120SD_01_04.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W53120SD_01_07.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W53120SD_01_08.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W53500BE_01_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W53500BE_01_03.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W54695FU_02_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W55417HU_01_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W55417HU_01_02.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W55417HU_01_03.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W55417HU_01_06.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W55417HU_01_08.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W55417HU_01_10.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W57574RB_01_03.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W57600TC_02_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W58956KC_01_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W58956KC_01_02.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W58956KC_01_04.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W59623HK_01_02.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W59623HK_01_03.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W59870BR_02_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W59870BR_02_04.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W59917ZE_01_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W60302WE_02_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W60302WE_02_02.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W60302WE_02_04.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W60328DR_01_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W60662AM_02_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W60662AM_02_02.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W60662AM_02_03.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W60662AM_02_05.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W61462BM_01_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W62082AC_02_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W62576WE_01_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W62576WE_01_02.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W62576WE_01_03.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W63258AD_01_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W63258AD_01_02.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W63258AD_01_03.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W63258AD_01_05.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W63258AD_01_06.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W63258AD_01_07.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W63389MN_01_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W63421UW_01_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W63526NZ_01_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W64043NB_03_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W64043NB_03_02.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W64078SW_01_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W64123ZW_03_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W64123ZW_03_02.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W64372SK_01_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W65044ZM_02_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W65819UX_01_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W65835UK_02_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W65835UK_02_02.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W65835UK_02_04.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W66137AN_01_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W66137AN_01_02.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W66539XR_02_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W67639RB_01_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W67639RB_01_02.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W68623UR_02_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W68623UR_02_02.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W69841EU_02_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W69870CR_01_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W69926HE_01_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W70004CZ_02_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W71323MA_01_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W71323MA_01_03.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W71323MA_01_05.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W71323MA_01_06.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W71323MA_01_07.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W71323MA_01_08.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W73513UU_01_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W73782AT_01_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W73782AT_01_02.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W73782AT_01_03.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W73782AT_01_04.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W73782AT_01_06.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W73782AT_01_07.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W73782AT_01_09.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W73782AT_01_10.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W73817HB_01_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W74140MW_01_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W74847WZ_01_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W74847WZ_01_04.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W75043NH_03_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W75043NH_03_02.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W75486CU_04_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W75486CU_04_05.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W75563TR_05_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W75563TR_05_03.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W75563TR_05_04.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W76350RE_02_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W76552NH_01_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W76552NH_01_03.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W77005BR_02_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W77005BR_02_03.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W77005BR_02_04.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W77005BR_02_05.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W77202HE_01_02.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W77504CA_02_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W77504CA_02_03.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W77504CA_02_04.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_W77504CA_02_05.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_M20048UA_02_02.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_M20048UA_02_05.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_M20048UA_03_01.shp does not exist. Skipping...
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\POI_after_Ser_hr\Drive_POI_after_ser_hr\Reprojected\POI_Drive_M24065HB_01_01.shp does not exist. Skipping...
# ...
# For hptripid M20303BA.03.04 with Total_T value of 5:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Drive_FOS\FOS_Drive_M20303BA_03_04.shp has 1 rows remaining.
# --------------------------------------------------
# For hptripid M20303BA.03.05 with Total_T value of 5:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Drive_FOS\FOS_Drive_M20303BA_03_05.shp has 1 rows remaining.
# --------------------------------------------------
# For hptripid M22480HA.01.03 with Total_T value of 15:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Drive_FOS\FOS_Drive_M22480HA_01_03.shp has 1632 rows remaining.
# --------------------------------------------------
# For hptripid M23859UR.02.01 with Total_T value of 155:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Drive_FOS\FOS_Drive_M23859UR_02_01.shp has 39150 rows remaining.
# --------------------------------------------------
# For hptripid M24264BC.01.01 with Total_T value of 180:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Drive_FOS\FOS_Drive_M24264BC_01_01.shp has 30195 rows remaining.
# --------------------------------------------------
# For hptripid M24264BC.01.03 with Total_T value of 25:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Drive_FOS\FOS_Drive_M24264BC_01_03.shp has 4227 rows remaining.
# --------------------------------------------------
# For hptripid M25979DB.01.01 with Total_T value of 15:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Drive_FOS\FOS_Drive_M25979DB_01_01.shp has 905 rows remaining.
# --------------------------------------------------
# For hptripid M25979DB.01.02 with Total_T value of 25:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Drive_FOS\FOS_Drive_M25979DB_01_02.shp has 5689 rows remaining.
# --------------------------------------------------
# For hptripid M26167UB.01.01 with Total_T value of 355:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Drive_FOS\FOS_Drive_M26167UB_01_01.shp has 38313 rows remaining.
# --------------------------------------------------
# For hptripid M26581WK.01.01 with Total_T value of 70:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Drive_FOS\FOS_Drive_M26581WK_01_01.shp has 23079 rows remaining.
# --------------------------------------------------
# For hptripid M29751KH.01.01 with Total_T value of 330:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Drive_FOS\FOS_Drive_M29751KH_01_01.shp has 39662 rows remaining.
# --------------------------------------------------
# For hptripid M31739FD.02.01 with Total_T value of 870:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Drive_FOS\FOS_Drive_M31739FD_02_01.shp has 24241 rows remaining.
# --------------------------------------------------
# For hptripid M32250AH.02.01 with Total_T value of 380:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Drive_FOS\FOS_Drive_M32250AH_02_01.shp has 30170 rows remaining.
# --------------------------------------------------
# For hptripid M32250AH.02.08 with Total_T value of 205:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Drive_FOS\FOS_Drive_M32250AH_02_08.shp has 32200 rows remaining.
# --------------------------------------------------
# For hptripid M32932TD.02.01 with Total_T value of 50:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Drive_FOS\FOS_Drive_M32932TD_02_01.shp has 5623 rows remaining.
# --------------------------------------------------
# For hptripid M32932TD.02.03 with Total_T value of 225:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Drive_FOS\FOS_Drive_M32932TD_02_03.shp has 20623 rows remaining.
# --------------------------------------------------
# For hptripid M33710ZH.02.04 with Total_T value of 50:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Drive_FOS\FOS_Drive_M33710ZH_02_04.shp has 6694 rows remaining.
# --------------------------------------------------
# For hptripid M33710ZH.02.12 with Total_T value of 5:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Drive_FOS\FOS_Drive_M33710ZH_02_12.shp has 63 rows remaining.
# --------------------------------------------------
# For hptripid M33710ZH.02.13 with Total_T value of 5:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Drive_FOS\FOS_Drive_M33710ZH_02_13.shp has 56 rows remaining.
# --------------------------------------------------
# For hptripid M34726XE.02.01 with Total_T value of 160:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Drive_FOS\FOS_Drive_M34726XE_02_01.shp has 34465 rows remaining.
# --------------------------------------------------
# For hptripid M34726XE.02.05 with Total_T value of 20:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Drive_FOS\FOS_Drive_M34726XE_02_05.shp has 2452 rows remaining.
# --------------------------------------------------
# For hptripid M34726XE.02.08 with Total_T value of 50:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Drive_FOS\FOS_Drive_M34726XE_02_08.shp has 20092 rows remaining.
# --------------------------------------------------
# For hptripid M34753ER.01.01 with Total_T value of 155:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Drive_FOS\FOS_Drive_M34753ER_01_01.shp has 31699 rows remaining.
# --------------------------------------------------
# For hptripid W10128EA.02.01 with Total_T value of 15:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Drive_FOS\FOS_Drive_W10128EA_02_01.shp has 1989 rows remaining.
# --------------------------------------------------
# For hptripid W10128EA.02.02 with Total_T value of 25:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Drive_FOS\FOS_Drive_W10128EA_02_02.shp has 9408 rows remaining.
# --------------------------------------------------
# For hptripid W10128EA.02.03 with Total_T value of 90:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Drive_FOS\FOS_Drive_W10128EA_02_03.shp has 37845 rows remaining.
# --------------------------------------------------
# For hptripid W10128EA.02.05 with Total_T value of 75:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Drive_FOS\FOS_Drive_W10128EA_02_05.shp has 31180 rows remaining.
# --------------------------------------------------
# For hptripid W10422NF.01.01 with Total_T value of 65:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Drive_FOS\FOS_Drive_W10422NF_01_01.shp has 6600 rows remaining.
# --------------------------------------------------
# For hptripid W10422NF.01.03 with Total_T value of 95:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Drive_FOS\FOS_Drive_W10422NF_01_03.shp has 23205 rows remaining.
# --------------------------------------------------
# For hptripid W11288SK.01.01 with Total_T value of 130:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Drive_FOS\FOS_Drive_W11288SK_01_01.shp has 25440 rows remaining.
# --------------------------------------------------
# For hptripid W11288SK.01.04 with Total_T value of 20:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Drive_FOS\FOS_Drive_W11288SK_01_04.shp has 6001 rows remaining.
# --------------------------------------------------
# For hptripid W11288SK.01.06 with Total_T value of 35:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Drive_FOS\FOS_Drive_W11288SK_01_06.shp has 19368 rows remaining.
# --------------------------------------------------
# For hptripid W11288SK.01.08 with Total_T value of 15:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Drive_FOS\FOS_Drive_W11288SK_01_08.shp has 1322 rows remaining.
# --------------------------------------------------
# For hptripid W11288SK.01.09 with Total_T value of 65:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Drive_FOS\FOS_Drive_W11288SK_01_09.shp has 25672 rows remaining.
# --------------------------------------------------
# For hptripid W11738KT.01.01 with Total_T value of 20:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Drive_FOS\FOS_Drive_W11738KT_01_01.shp has 3123 rows remaining.
# --------------------------------------------------
# For hptripid W11738KT.01.03 with Total_T value of 25:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Drive_FOS\FOS_Drive_W11738KT_01_03.shp has 8598 rows remaining.
# --------------------------------------------------
# For hptripid W11738KT.01.05 with Total_T value of 50:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Drive_FOS\FOS_Drive_W11738KT_01_05.shp has 19051 rows remaining.
# --------------------------------------------------
# For hptripid W11748DX.01.01 with Total_T value of 5:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Drive_FOS\FOS_Drive_W11748DX_01_01.shp has 68 rows remaining.
# --------------------------------------------------
# For hptripid W12477HK.01.01 with Total_T value of 40:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Drive_FOS\FOS_Drive_W12477HK_01_01.shp has 20654 rows remaining.
# --------------------------------------------------
# For hptripid W14267FE.02.01 with Total_T value of 170:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Drive_FOS\FOS_Drive_W14267FE_02_01.shp has 29478 rows remaining.
# --------------------------------------------------
# For hptripid W14937FK.01.03 with Total_T value of 85:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Drive_FOS\FOS_Drive_W14937FK_01_03.shp has 8968 rows remaining.
# --------------------------------------------------
# For hptripid W14937FK.01.05 with Total_T value of 310:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Drive_FOS\FOS_Drive_W14937FK_01_05.shp has 35171 rows remaining.
# --------------------------------------------------
# For hptripid W15806SE.02.01 with Total_T value of 190:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Drive_FOS\FOS_Drive_W15806SE_02_01.shp has 34967 rows remaining.
# --------------------------------------------------
# For hptripid W16125ED.01.01 with Total_T value of 35:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Drive_FOS\FOS_Drive_W16125ED_01_01.shp has 20618 rows remaining.
# --------------------------------------------------
# For hptripid W16652KT.02.03 with Total_T value of 375:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Drive_FOS\FOS_Drive_W16652KT_02_03.shp has 39943 rows remaining.
# --------------------------------------------------
# For hptripid W16727SE.01.01 with Total_T value of 5:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Drive_FOS\FOS_Drive_W16727SE_01_01.shp has 133 rows remaining.
# --------------------------------------------------
# For hptripid W16727SE.01.02 with Total_T value of 150:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Drive_FOS\FOS_Drive_W16727SE_01_02.shp has 30165 rows remaining.
# --------------------------------------------------
# For hptripid W16727SE.01.04 with Total_T value of 160:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Drive_FOS\FOS_Drive_W16727SE_01_04.shp has 39619 rows remaining.
# --------------------------------------------------
# For hptripid W17047UX.02.01 with Total_T value of 120:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Drive_FOS\FOS_Drive_W17047UX_02_01.shp has 39553 rows remaining.
# --------------------------------------------------
# For hptripid W17428ME.01.01 with Total_T value of 430:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Drive_FOS\FOS_Drive_W17428ME_01_01.shp has 23410 rows remaining.
# --------------------------------------------------
# For hptripid W17428ME.01.03 with Total_T value of 85:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Drive_FOS\FOS_Drive_W17428ME_01_03.shp has 26801 rows remaining.
# --------------------------------------------------
# For hptripid W17928SZ.02.01 with Total_T value of 5:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Drive_FOS\FOS_Drive_W17928SZ_02_01.shp has 295 rows remaining.
# --------------------------------------------------
# For hptripid W17928SZ.02.02 with Total_T value of 5:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Drive_FOS\FOS_Drive_W17928SZ_02_02.shp has 295 rows remaining.
# --------------------------------------------------
# For hptripid W17928SZ.02.04 with Total_T value of 5:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Drive_FOS\FOS_Drive_W17928SZ_02_04.shp has 536 rows remaining.
# --------------------------------------------------
# For hptripid W17928SZ.02.05 with Total_T value of 35:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Drive_FOS\FOS_Drive_W17928SZ_02_05.shp has 6251 rows remaining.
# --------------------------------------------------
# For hptripid W18700CA.01.01 with Total_T value of 70:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Drive_FOS\FOS_Drive_W18700CA_01_01.shp has 9494 rows remaining.
# --------------------------------------------------
# For hptripid W19590BK.02.01 with Total_T value of 10:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Drive_FOS\FOS_Drive_W19590BK_02_01.shp has 924 rows remaining.
# --------------------------------------------------
# For hptripid W19590BK.02.02 with Total_T value of 10:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Drive_FOS\FOS_Drive_W19590BK_02_02.shp has 1076 rows remaining.
# --------------------------------------------------
# For hptripid W19590BK.02.03 with Total_T value of 10:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Drive_FOS\FOS_Drive_W19590BK_02_03.shp has 1500 rows remaining.
# --------------------------------------------------
# For hptripid W19590BK.02.04 with Total_T value of 10:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Drive_FOS\FOS_Drive_W19590BK_02_04.shp has 1498 rows remaining.
# --------------------------------------------------
# For hptripid W19974SN.01.01 with Total_T value of 275:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Drive_FOS\FOS_Drive_W19974SN_01_01.shp has 37924 rows remaining.
# --------------------------------------------------
# For hptripid W20535EH.01.01 with Total_T value of 20:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Drive_FOS\FOS_Drive_W20535EH_01_01.shp has 2135 rows remaining.
# --------------------------------------------------
# For hptripid W21158UX.02.04 with Total_T value of 70:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Drive_FOS\FOS_Drive_W21158UX_02_04.shp has 0 rows remaining.
# --------------------------------------------------
# For hptripid W21828XK.03.01 with Total_T value of 10:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Drive_FOS\FOS_Drive_W21828XK_03_01.shp has 1121 rows remaining.
# --------------------------------------------------
# For hptripid W21828XK.03.02 with Total_T value of 15:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Drive_FOS\FOS_Drive_W21828XK_03_02.shp has 2447 rows remaining.
# --------------------------------------------------
# For hptripid W22639ZK.03.01 with Total_T value of 55:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Drive_FOS\FOS_Drive_W22639ZK_03_01.shp has 1 rows remaining.
# --------------------------------------------------
# For hptripid W24247ZA.01.01 with Total_T value of 300:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Drive_FOS\FOS_Drive_W24247ZA_01_01.shp has 39943 rows remaining.
# --------------------------------------------------
# For hptripid W24659WW.02.01 with Total_T value of 125:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Drive_FOS\FOS_Drive_W24659WW_02_01.shp has 34182 rows remaining.
# --------------------------------------------------
# For hptripid W24914AW.01.01 with Total_T value of 475:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Drive_FOS\FOS_Drive_W24914AW_01_01.shp has 24340 rows remaining.
# --------------------------------------------------
# For hptripid W24966TN.01.01 with Total_T value of 550:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Drive_FOS\FOS_Drive_W24966TN_01_01.shp has 34967 rows remaining.
# --------------------------------------------------
# For hptripid W25159US.02.02 with Total_T value of 15:
# Shapefile E:\Space-Time-Prism-Model\PwoD STP\FOS_Count\Drive_FOS\FOS_Drive_W25159US_02_02.shp has 451 rows remaining.
# --------------------------------------------------
# The script took 945029.5314347744 seconds to complete.
